# %%
import os
import torch

from get_loader import (VideoDataset_to_VideoCaptionsLoader, Vocabulary,
                        get_loader)
from trainer import Trainer
import pandas as pd

# %%
gpu = '0'
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = gpu

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

checkpoints_dir = os.path.join("checkpoints")
output_csv_dir = os.path.join("results")

batch_size = 128

# %%
# Get the dataset and dataloaders
dataset_folder = os.path.join("datasets", "MSVD")
vocab_pkl = os.path.join(dataset_folder, "metadata", "vocab.pkl")
vocab = Vocabulary.load(vocab_pkl)

val_loader, _ = get_loader(
    root_dir=dataset_folder,
    split="val",
    batch_size=batch_size,
    vocab_pkl=vocab_pkl,
)
test_loader, _ = get_loader(
    root_dir=dataset_folder,
    split="test",
    batch_size=batch_size,
    vocab_pkl=vocab_pkl,
)

val_vidCap_loader = VideoDataset_to_VideoCaptionsLoader(val_loader.dataset, batch_size)
test_vidCap_loader = VideoDataset_to_VideoCaptionsLoader(test_loader.dataset, batch_size)
# Out:
# Before integrity check: 3720
# After integrity check: 2562
# After removing unverified: 1055
# Loading Vocab: datasets\MSVD\metadata\vocab.pkl
# Before integrity check: 24452
# After integrity check: 19061
# After removing unverified: 7671
# Loading Vocab: datasets\MSVD\metadata\vocab.pkl

# %%
# Get a trainer for model evaluation
tr = Trainer(checkpoint_name='test.ckpt', log_dir='trash')
tr.device = device

# Load the models and predict
for ckpt in os.listdir(checkpoints_dir):
    if ckpt.endswith('_best.pt'):
        print("\nLoading model from checkpoint:", ckpt)
        model = torch.load(os.path.join(checkpoints_dir, ckpt))

        for loader, phase in zip([val_vidCap_loader, test_vidCap_loader], ['val', 'test']):
            _, true_captions, generated_captions = tr.eval(model, val_vidCap_loader, training_phase=phase, epoch=0, get_scores=False)

            model_name = ckpt.split('_best')[0]
            model_results = {
                'generated_captions': generated_captions,
                'true_captions': true_captions,
            }

            if not os.path.isdir(os.path.join(output_csv_dir, phase)):
                os.makedirs(os.path.join(output_csv_dir, phase))

            df = pd.DataFrame(model_results)
            df.to_csv(
                os.path.join(output_csv_dir, phase, f"{model_name}.csv"),
                header=True,
                columns=["generated_captions", "true_captions"],
            )
# Out:
# > [a man is slicing a loaf of bread .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a woman is putting a potato .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a man is playing with a ball .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is playing a goal of wood .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is riding a horse .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a man is lifting a car .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is riding a horse .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a boy is playing with a ball .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a woman is riding a horse .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a woman is chopping a potato .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is playing a guitar .] (a boy is playing a key - board between the people .)
#
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.65it/s]
# EVAL :   0%|          | 0/1 [00:00<?, ?it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [a man is slicing a loaf of bread .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a woman is putting a potato .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a man is playing with a ball .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is playing a goal of wood .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is riding a horse .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a man is lifting a car .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is riding a horse .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a boy is playing with a ball .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a woman is riding a horse .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a woman is chopping a potato .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is playing a guitar .] (a boy is playing a key - board between the people .)
#
#
# Loading model from checkpoint: SA-LSTM_50_epochs_reg_5e-4_video_audio_local_1_5e-5_best.pt
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.41it/s]
# EVAL :   0%|          | 0/1 [00:00<?, ?it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [someone is pouring water into a bowl .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a woman is slicing some vegetables .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a man is playing the guitar .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is playing the guitar .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is riding a bike on the road .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a man is skiing a rabbit .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is playing a computer in a car .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a girl is scooping a <UNK> on the road .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a man is walking the guitar .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a woman is applying to her hair .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is playing the guitar .] (a boy is playing a key - board between the people .)
#
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# EVAL :   0%|          | 0/1 [00:00<?, ?it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [someone is pouring water into a bowl .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a woman is slicing some vegetables .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a man is playing the guitar .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is playing the guitar .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is riding a bike on the road .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a man is skiing a rabbit .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is playing a computer in a car .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a girl is scooping a <UNK> on the road .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a man is walking the guitar .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a woman is applying to her hair .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is playing the guitar .] (a boy is playing a key - board between the people .)
#
#
# Loading model from checkpoint: SA-LSTM_50_epochs_reg_5e-4_video_global_0.1_best.pt
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [a man is cutting a bun into pieces .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a woman is talking a piece of paper .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a man is playing with a ball .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is scoring a basketball shot at a lying .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is playing with a ball .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a man is cutting a piece .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is swinging on a rope .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a man is playing with a ball .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a woman is riding a horse in a field .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a girl is talking with action .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is playing the guitar .] (a boy is playing a key - board between the people .)
#
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.43it/s]
# EVAL :   0%|          | 0/1 [00:00<?, ?it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [a man is cutting a bun into pieces .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a woman is talking a piece of paper .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a man is playing with a ball .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is scoring a basketball shot at a lying .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is playing with a ball .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a man is cutting a piece .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is swinging on a rope .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a man is playing with a ball .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a woman is riding a horse in a field .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a girl is talking with action .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is playing the guitar .] (a boy is playing a key - board between the people .)
#
#
# Loading model from checkpoint: SA-LSTM_50_epochs_reg_5e-4_video_global_0.5_best.pt
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.53it/s]
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.35it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [a man is pouring seasoning into a bowl of water .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a woman is cutting a piece of garlic .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a man is slicing a green ball .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is cutting a goal .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is cutting a ball of a paper and then to a room .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a cat is <UNK> a long .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a young man is walking a gun .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a man is doing the head .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a woman is running on a horse .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a woman is cutting a woman .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is singing while playing the guitar .] (a boy is playing a key - board between the people .)
#
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# EVAL :   0%|          | 0/1 [00:00<?, ?it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [a man is pouring seasoning into a bowl of water .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a woman is cutting a piece of garlic .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a man is slicing a green ball .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is cutting a goal .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is cutting a ball of a paper and then to a room .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a cat is <UNK> a long .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a young man is walking a gun .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a man is doing the head .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a woman is running on a horse .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a woman is cutting a woman .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is singing while playing the guitar .] (a boy is playing a key - board between the people .)
#
#
# Loading model from checkpoint: SA-LSTM_50_epochs_reg_5e-4_video_global_1_best.pt
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.00it/s]
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.38it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [a man is slicing a loaf of bread .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a man is slicing a cucumber .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a man is doing a motorcycle .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is playing a motorcycle .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is riding a horse with a knife .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a woman is riding a horse .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is riding a horse .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a man is doing a motorcycle on a motorcycle .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a man is riding a horse .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a woman is using a tomato .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is playing guitar and singing .] (a boy is playing a key - board between the people .)
#
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.35it/s]
# EVAL :   0%|          | 0/1 [00:00<?, ?it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [a man is slicing a loaf of bread .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a man is slicing a cucumber .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a man is doing a motorcycle .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is playing a motorcycle .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is riding a horse with a knife .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a woman is riding a horse .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is riding a horse .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a man is doing a motorcycle on a motorcycle .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a man is riding a horse .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a woman is using a tomato .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is playing guitar and singing .] (a boy is playing a key - board between the people .)
#
#
# Loading model from checkpoint: SA-LSTM_50_epochs_reg_5e-4_video_local_0.1_best.pt
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [a person is pouring ingredients in a bowl .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a man is talking with a knife .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a woman is <UNK> an onion .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is playing a guitar .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is playing a guitar .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a person is peeling a piece of paper .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is shooting a gun .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a man is playing a guitar .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a man is riding a motorcycle .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a girl is cutting .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man plays the guitar .] (a boy is playing a key - board between the people .)
#
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.43it/s]
# EVAL :   0%|          | 0/1 [00:00<?, ?it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [a person is pouring ingredients in a bowl .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a man is talking with a knife .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a woman is <UNK> an onion .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is playing a guitar .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is playing a guitar .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a person is peeling a piece of paper .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is shooting a gun .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a man is playing a guitar .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a man is riding a motorcycle .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a girl is cutting .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man plays the guitar .] (a boy is playing a key - board between the people .)
#
#
# Loading model from checkpoint: SA-LSTM_50_epochs_reg_5e-4_video_local_0.5_best.pt
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# EVAL :   0%|          | 0/1 [00:00<?, ?it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [a person is pouring a pitcher of meat into the water .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a woman is cutting a potato .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a man is holding a small .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is making a motorcycle game .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a woman is doing bicycle .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a man is doing a card .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is riding a white horse .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a woman is playing a piano .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a woman is holding a horse .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a woman is peeling a potato .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is playing a guitar .] (a boy is playing a key - board between the people .)
#
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.13it/s]
# EVAL :   0%|          | 0/1 [00:00<?, ?it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [a person is pouring a pitcher of meat into the water .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a woman is cutting a potato .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a man is holding a small .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is making a motorcycle game .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a woman is doing bicycle .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a man is doing a card .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is riding a white horse .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a woman is playing a piano .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a woman is holding a horse .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a woman is peeling a potato .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is playing a guitar .] (a boy is playing a key - board between the people .)
#
#
# Loading model from checkpoint: SA-LSTM_50_epochs_reg_5e-4_video_local_1_best.pt
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.21it/s]
# EVAL :   0%|          | 0/1 [00:00<?, ?it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [a person is adding chopped vegetables into a bowl .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a woman is slicing a potato .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a woman is riding a horse .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is cutting a <UNK> .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is playing a guitar .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a woman is cutting a <UNK> .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is walking a horse .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a man is playing the piano .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a man is riding a horse .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a woman is slicing a <UNK> .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is playing a guitar .] (a boy is playing a key - board between the people .)
#
# EVAL : 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# Example captions: key >> [generated] (ground_truth)
# bQJQGoJF7_k_162_169 >> [a person is adding chopped vegetables into a bowl .] (a man is filling up a bag with meat .)
# bSrpvMSuhPM_17_31 >> [a woman is slicing a potato .] (a man is talking to a woman .)
# bXsKw3TOQXs_30_55 >> [a woman is riding a horse .] (a small piece of paper is being folded .)
# b_BuSVZwq6M_1_9 >> [a man is cutting a <UNK> .] (a man makes a great play in a cricket game .)
# bb6V0Grtub4_174_185 >> [a man is playing a guitar .] (a man is playing on drums .)
# bkazguPsusc_74_85 >> [a woman is cutting a <UNK> .] (a cat is sliding under a couch .)
# bmxIurBrW5s_51_70 >> [a man is walking a horse .] (a woman practicing a volleyball)
# bruzcOyIGeg_4_12 >> [a man is playing the piano .] (a man drives a remote control car .)
# btuxO-C2IzE_64_72 >> [a man is riding a horse .] (a lion jumps up and is hugged and petted by two long - <UNK> men .)
# buJ5HDCinrM_150_166 >> [a woman is slicing a <UNK> .] (a woman is putting make up on her face .)
# bxDlC7YV5is_0_12 >> [a man is playing a guitar .] (a boy is playing a key - board between the people .)

# %%
train_loader, train_dataset = get_loader(
    root_dir=dataset_folder,
    split="train",
    batch_size=batch_size,
    vocab_pkl=vocab_pkl,
    # normalize=exp['normalize_dataset'],
)
val_loader, val_dataset = get_loader(
    root_dir=dataset_folder,
    split="val",
    batch_size=batch_size,
    vocab_pkl=vocab_pkl,
    # normalize=exp['normalize_dataset'],
)
test_loader, test_dataset = get_loader(
    root_dir=dataset_folder,
    split="test",
    batch_size=batch_size,
    vocab_pkl=vocab_pkl,
    # normalize=exp['normalize_dataset'],
)

print("Train:", len(train_dataset.metadata['VideoID'].unique()))
print("Validation:", len(val_dataset.metadata['VideoID'].unique()))
print("Test:", len(test_dataset.metadata['VideoID'].unique()))
# Out:
# Before integrity check: 42990
# After integrity check: 32509
# After removing unverified: 13291
# Loading Vocab: datasets\MSVD\metadata\vocab.pkl
# Before integrity check: 3720
# After integrity check: 2562
# After removing unverified: 1055
# Loading Vocab: datasets\MSVD\metadata\vocab.pkl
# Before integrity check: 24452
# After integrity check: 19061
# After removing unverified: 7671
# Loading Vocab: datasets\MSVD\metadata\vocab.pkl
# Train: 624
# Validation: 60
# Test: 392
